# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including NumPy and Matplotlib.

# %% [markdown]
# # Generate Dummy Data
# Generate dummy data using the gen_dummy_data() function and print the data.

# %%
import numpy as np
import time
from collections import deque
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from datetime import datetime, timedelta, timezone
import matplotlib
import matplotlib.dates as mdates
# Define a timezone offset for UTC+9

# Initialize a deque with a maximum length of 10 (adjustable)
queue = deque(maxlen=10)

# Set up the plot


utc_plus_9 = timezone(timedelta(hours=9))

while True:
    fig, ax = plt.subplots()
    ax.set_title("Real-time Time Series Plot")
    ax.set_xlabel("Timestamp")
    ax.set_ylabel("Vehicle Count")
    ax.set_ylim(0, 25)  # Set the y-axis range from 0 to 100
    line, = ax.plot([], [], 'b-', marker='o')  # Initialize an empty line for the plot
    # Get the current time with the UTC+9 timezone
    current_time_utc_plus_9 = datetime.now(utc_plus_9)
    # current_time_utc_plus_9 = current_time_utc_plus_9.strftime('%H:%M:%S')
    print(type(current_time_utc_plus_9))

    queue.append([current_time_utc_plus_9,np.random.randint(25)])  # Automatically removes oldest if full
    
    # Extract data from the queue for plotting
    times, values = zip(*queue)
    print(str(times))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    # Update the plot's x and y data
    times = matplotlib.dates.date2num(times)
    line.set_data(times, values)
    ax.set_xticks(times)  # Set x-axis ticks to the timestamp values
    ax.set_yticks(range(0, 30, 10))  # Set y-axis ticks from 0 to 100 with steps of 10
    ax.relim()         # Adjust plot limits
    ax.autoscale_view() # Rescale view to fit new data
    
    # Rotate x-axis labels for readability
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
    # plt.savefig('time_series.png')
    
    time.sleep(1)
    plt.close(fig)
# Out:
# <class 'datetime.datetime'>
# (datetime.datetime(2024, 11, 5, 0, 31, 25, 799386, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))),)
# <class 'datetime.datetime'>
# (datetime.datetime(2024, 11, 5, 0, 31, 25, 799386, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))), datetime.datetime(2024, 11, 5, 0, 31, 26, 901210, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))))
# <class 'datetime.datetime'>
# (datetime.datetime(2024, 11, 5, 0, 31, 25, 799386, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))), datetime.datetime(2024, 11, 5, 0, 31, 26, 901210, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))), datetime.datetime(2024, 11, 5, 0, 31, 27, 999561, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400))))
# <class 'datetime.datetime'>
# ...

# %%
print(current_time_utc_plus_9)
# Out:
# 2024-11-02 18:26:29.807051+09:00

# %%
a = np.array([1, 2, 3, 4])
labels = ['light', 'normal', 'heavy', 'high']
# plt.pie(a, labels=labels, autopct='%1.1f%%', colors = ['green', 'yellow','orange', 'red'])
plt.figsize=(30, 30)
plt.bar(labels, a, color=['green', 'yellow','orange', 'red'])
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Define colors and labels
colors = ['green', 'yellow', 'orange', 'red']
labels = ['light', 'normal', 'heavy', 'high']

# Create a figure and axis
fig, ax = plt.subplots()

# Create custom legend handles with increased line width
legend_handles = [Line2D([0], [0], color=color, lw=4) for color in colors]

# Add the legend to the plot
ax.legend(legend_handles, labels)

# Display the plot
plt.show()

# %%
global queue
queue.add(traffic_pie)

# %%
if 1 in [1 for i in data[1:] if i!= 0]:

# %%
plt.pie(np.array([0, 0, 1, 0]), 
        labels = ['0', '1', '2', '3'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef87bcc510>,
# ...
#  [Text(1.1, 0.0, '0'),
#   Text(1.1, 0.0, '1'),
#   Text(-1.1, 1.3471114790620887e-16, '2'),
#   Text(1.1, -2.6942229581241775e-16, '3')])

# %%
a = np.array([1, 2])
list(a)
# Out:
# [1, 2]

# %%
def gen_dummy_data():
    return [np.random.randint(0, 100) for _ in range(4)]

# %%
# Generate Dummy Data
data = gen_dummy_data()  # Generate dummy data using the gen_dummy_data() function
print(data)  # Print the generated data
labels = ['Car', 'Truck', 'Bus', 'Motorcycle']  # Define labels for the data

testcase = [2, 0, 0, 1]
data = testcase
non_zere_labels = [labels[idx] for idx, i in enumerate(data) if i!= 0]
non_zero_data = [i for i in data if i!= 0]

# Create a pie chart showing the distribution of vehicle counts
plt.pie(
    np.array(non_zero_data), 
    labels=non_zere_labels, 
    autopct='%1.1f%%'  # Show numbers inside the pie chart
)
plt.legend()
# plt.savefig('static/pie_chart.png') # Display the pie chart
# Out:
# [73, 25, 10, 10]
